# %%
import pandas as pd
# Making the import
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('players_21.csv')
pd.options.display.max_columns = None

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3         188545  https://sofifa.com/player/188545/robert-lewand...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 18939     256679  https://sofifa.com/player/256679/kevin-angulo/...
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   33
# ...

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg   league_rank  \
# count   18944.000000  18944.000000  18944.000000  18944.000000  18719.000000
# mean   226242.402872     25.225823    181.190773     75.016892      1.357070
# std     27171.091056      4.697354      6.825672      7.057140      0.739327
# min        41.000000     16.000000    155.000000     50.000000      1.000000
# 25%    210030.500000     21.000000    176.000000     70.000000      1.000000
# 50%    232314.500000     25.000000    181.000000     75.000000      1.000000
# 75%    246760.250000     29.000000    186.000000     80.000000      1.000000
# max    258970.000000     53.000000    206.000000    110.000000      4.000000
#
#             overall     potential     value_eur       wage_eur  \
# count  18944.000000  18944.000000  1.894400e+04   18944.000000
# mean      65.677787     71.086729  2.224813e+06    8675.852513
# std        7.002278      6.109985  5.102486e+06   19654.774894
# ...

# %%
pd.options.display.max_rows = None
df.isna().sum()
# Out:
# sofifa_id                         0
# player_url                        0
# short_name                        0
# long_name                         0
# age                               0
# dob                               0
# height_cm                         0
# weight_kg                         0
# nationality                       0
# club_name                       225
# league_name                     225
# league_rank                     225
# overall                           0
# potential                         0
# value_eur                         0
# wage_eur                          0
# player_positions                  0
# preferred_foot                    0
# international_reputation          0
# weak_foot                         0
# skill_moves                       0
# work_rate                         0
# body_type                         0
# real_face                         0
# release_clause_eur              995
# player_tags                   17536
# ...

# %%
df.loc[:, df.isnull().any()].columns
# Out:
# Index(['club_name', 'league_name', 'league_rank', 'release_clause_eur',
#        'player_tags', 'team_position', 'team_jersey_number', 'loaned_from',
#        'joined', 'contract_valid_until', 'nation_position',
#        'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking',
#        'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits',
#        'defending_marking'],
#       dtype='object')

# %%
df.isna().sum()/(len(df))*100
# Out:
# sofifa_id                       0.000000
# player_url                      0.000000
# short_name                      0.000000
# long_name                       0.000000
# age                             0.000000
# dob                             0.000000
# height_cm                       0.000000
# weight_kg                       0.000000
# nationality                     0.000000
# club_name                       1.187711
# league_name                     1.187711
# league_rank                     1.187711
# overall                         0.000000
# potential                       0.000000
# value_eur                       0.000000
# wage_eur                        0.000000
# player_positions                0.000000
# preferred_foot                  0.000000
# international_reputation        0.000000
# weak_foot                       0.000000
# skill_moves                     0.000000
# work_rate                       0.000000
# body_type                       0.000000
# ...

# %%
df_count = df.groupby('league_name').count().sort_values('sofifa_id',ascending=False)['sofifa_id']
df_count
# Out:
# league_name
# English League Championship             709
# USA Major League Soccer                 701
# Argentina Primera División              659
# English Premier League                  654
# Italian Serie A                         645
# Spain Primera Division                  645
# English League One                      630
# Spanish Segunda División                619
# English League Two                      605
# French Ligue 1                          600
# Turkish Süper Lig                       589
# German 1. Bundesliga                    548
# French Ligue 2                          546
# German 3. Bundesliga                    522
# Japanese J. League Division 1           521
# Portuguese Liga ZON SAGRES              510
# Mexican Liga MX                         509
# German 2. Bundesliga                    507
# Belgian Jupiler Pro League              492
# Holland Eredivisie                      466
# Chinese Super League                    436
# ...

# %%
# Top leagues in Fifa
p = figure(x_range=np.array(df_count.index[:5]), plot_width=900, title="Leagues")

p.vbar(x=np.array(df_count.index[:5]), top=np.array(df_count)[:5], width=0.9)


p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="9e9a8b04-9119-4489-a57f-6647d10f868d" data-root-id="5643"></div>

# %%
# Bottom leagues in Fifa
p = figure(x_range=np.array(df_count.index[-5:]), plot_width=900, title="Leagues")

p.vbar(x=np.array(df_count.index[-5:]), top=np.array(df_count)[-5:], width=0.9)


p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="b5b94027-6be6-4221-b5c4-ddf3a9d73a16" data-root-id="6225"></div>

# %%
# Average hieght per league, average weight, average everything, per league, per COUNTRY

# %%
df_overall = df.groupby('league_name').mean()['overall'].sort_values(ascending=False)
df_overall

# %%
# Top leagues in Fifa
p = figure(x_range=np.array(df_overall.index[:5]), plot_width=900, title="Leagues")

p.vbar(x=np.array(df_overall.index[:5]), top=np.array(df_overall)[:5], width=0.9)


p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="4e4ad26d-a97b-4ae2-afa0-f4f5afc1010f" data-root-id="6528"></div>

# %%
# Bottom leagues in Fifa
p = figure(x_range=np.array(df_overall.index[-5:]), plot_width=900, title="Leagues")

p.vbar(x=np.array(df_overall.index[-5:]), top=np.array(df_overall)[-5:], width=0.9)


p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="d39a9461-ee8b-48a7-935f-d6402bf457aa" data-root-id="6839"></div>

# %%
df_country = df.groupby('nationality').mean()['overall'].sort_values(ascending=False)
df_country
# Out:
# nationality
# Tanzania                    76.000000
# Chad                        73.000000
# Mozambique                  72.200000
# Bermuda                     72.000000
# Armenia                     71.500000
# Libya                       71.250000
# Egypt                       71.172414
# New Caledonia               71.000000
# Puerto Rico                 71.000000
# Brazil                      70.961669
# Ukraine                     70.815385
# Algeria                     70.807692
# Iraq                        70.750000
# Iran                        70.333333
# Central African Republic    70.250000
# Russia                      70.207792
# São Tomé & Príncipe         70.000000
# Malawi                      70.000000
# Czech Republic              69.864865
# Gabon                       69.812500
# Portugal                    69.804533
# Syria                       69.750000
# Morocco                     69.750000
# Croatia                     69.318182
# ...

# %%
# Top leagues in Fifa
p = figure(x_range=np.array(df_country.index[:5]), plot_width=900, title="Leagues")

p.vbar(x=np.array(df_country.index[:5]), top=np.array(df_country)[:5], width=0.9)


p.y_range.start = 0

show(p)
# Out:
#   <div class="bk-root" id="aab2dc39-c482-4584-8f2f-d2a95042ebe5" data-root-id="7158"></div>

# %%
df.groupby('nationality').count()
# Out:
#                           sofifa_id  player_url  short_name  long_name   age  \
# nationality
# Afghanistan                       2           2           2          2     2
# Albania                          49          49          49         49    49
# Algeria                          52          52          52         52    52
# Andorra                           1           1           1          1     1
# Angola                           16          16          16         16    16
# Antigua & Barbuda                 4           4           4          4     4
# Argentina                       936         936         936        936   936
# Armenia                           4           4           4          4     4
# Aruba                             1           1           1          1     1
# Australia                       241         241         241        241   241
# Austria                         321         321         321        321   321
# ...
